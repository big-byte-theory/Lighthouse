# %%
import numpy as np  # numpy!
import seaborn as sns # visualisation!
import matplotlib.pyplot as plt # visualisation!
import pandas as pd # dataframes & data analysis!
from ast import literal_eval
import re #for Regex
from dotenv import load_dotenv
import os

# %% [markdown]
# ### MongoDb Connection

# %%
from pymongo import MongoClient

#get secrets from .env
load_dotenv()

uri = os.getenv('URI')

# Create a new client and connect to the server
client = MongoClient(uri)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['lighthouse']

# Get collection 
collection = db['llm_datas']
collection.find_one()

# get all in collection 
#documents = collection.find()

# Print the documents
#for document in documents:
#    print(document)
# Out:
# {'_id': ObjectId('6697b3b814a5850299849064'),
#  'llm_data_id': 1,
#  'name': 'ToyMix',
#  'type_id': ObjectId('6697b42814a585029984929e'),
#  'organization_id': ObjectId('6697b54414a5850299849566'),
#  'description_id': ObjectId('6697c27414a5850299849af3'),
#  'created_date_id': ObjectId('6697c08414a58502998497c4'),
#  'url_id': ObjectId('6697c29714a5850299849ba8'),
#  'datasheet_id': ObjectId('6697c24314a585029984994c'),
#  'modality_id': ObjectId('6697d1719fcba3f46768dc4b'),
#  'size_id': ObjectId('6697d1fb9fcba3f46768dd5d'),
#  'sample_id': ObjectId('6697bf5414a58502998496df'),
#  'analysis_id': ObjectId('6697c1a414a58502998498d9'),
#  'dependencies_id': ObjectId('669a3ac8db0298c298c50a20'),
#  'included_id': ObjectId('6697d1449fcba3f46768db83'),
#  'excluded_id': ObjectId('6697c2cf14a5850299849cff'),
#  'quality_control_id': ObjectId('6697d1dc9fcba3f46768dd33'),
#  'access_id': ObjectId('6697bcf614a58502998495cc'),
#  'license_id': ObjectId('6697be3f14a58502998495ee'),
#  'intended_uses_id': ObjectId('6697d15a9fcba3f46768dbdf'),
#  'prohibited_uses_id': ObjectId('6697d1ce9fcba3f46768dce0'),
#  'monitoring_id': ObjectId('6697bea514a58502998496d1'),
#  'feedback_id': ObjectId('6697d1359fcba3f46768db61'),
#  'model_card_id': ObjectId('6697be7914a58502998496bc'),
#  'training_emissions_id': ObjectId('6697d2239fcba3f46768de3c'),
#  'training_time_id': ObjectId('6697d2479fcba3f46768df01'),
#  'training_hardware_id': ObjectId('6697d2339fcba3f46768deb3'),
#  'adaptation_id': ObjectId('6697bd5814a58502998495d6'),
#  'output_space_id': ObjectId('6697d1ac9fcba3f46768dc98'),
#  'terms_of_service_id': ObjectId('6697d2109fcba3f46768de26'),
#  'monthly_active_users_id': ObjectId('6697d1919fcba3f46768dc76'),
#  'user_distribution_id': ObjectId('6697bfe914a58502998496ea'),
#  'failures_id': ObjectId('6697d11f9fcba3f46768daa6')}

# %%
## loop through documents in LLM_data

def update_llm_data_with_objects():
    
    llm_collection = db['llm_datas']
    
    for doc in llm_collection.find():
        updates = {}
        model_name = doc["name"]
        document_id = doc["_id"]
        for field, ref_id in doc.items():
            if field.endswith("_id"):  # Identify reference fields
                if field != '_id' and field != 'llm_data_id':
                    x = field.rsplit("_", 1)
                    collection_name = 'llm_' + x[0]
                    #print(f"{field}: {ref_id}")
                    #print(collection_name)
                    
                    # Perform lookup for the corresponding collection
                    collection_name = db[collection_name]
                    referenced_doc = collection_name.find_one({field: ref_id})
                    if referenced_doc:  # Check if referenced document exists
                        updates[field] = referenced_doc['_id']  # Update with the objectid from collection
                        #print(referenced_doc['_id'])
         
        #print(updates)            
         # Replace document_id with the actual ID of the document you want to update
        result = llm_collection.update_one({"_id": document_id}, {"$set": updates})
        
        if result.matched_count > 0:
            print(f"Document with ID {document_id}, model: {model_name} updated successfully.")
        else:
            print(f"No document found with ID {document_id}.")
                
        
update_llm_data_with_objects()
# Out:
# Document with ID 6697b3b814a5850299849064, model: ToyMix updated successfully.
# Document with ID 6697b3b814a5850299849065, model: LargeMix updated successfully.
# Document with ID 6697b3b814a5850299849066, model: UltraLarge updated successfully.
# Document with ID 6697b3b814a5850299849067, model: Lag-LLaMA updated successfully.
# Document with ID 6697b3b814a5850299849068, model: Prithvi updated successfully.
# Document with ID 6697b3b814a5850299849069, model: Watsonx.ai updated successfully.
# Document with ID 6697b3b814a585029984906a, model: Granite updated successfully.
# Document with ID 6697b3b814a585029984906b, model: Animagine XL 3.1 updated successfully.
# Document with ID 6697b3b814a585029984906c, model: Portkey updated successfully.
# Document with ID 6697b3b814a585029984906d, model: Viable updated successfully.
# Document with ID 6697b3b814a585029984906e, model: Auto-GPT updated successfully.
# Document with ID 6697b3b814a585029984906f, model: Bark updated successfully.
# Document with ID 6697b3b814a5850299849070, model: ChatGPT powered by OBO updated successfully.
# Document with ID 6697b3b814a5850299849071, model: GPT-JT updated successfully.
# Document with ID 6697b3b814a5850299849072, model: GPT-NeoXT-Chat-Base updated successfully.
# Document with ID 6697b3b814a5850299849073, model: OpenChatKit moderation model updated successfully.
# Document with ID 6697b3b814a5850299849074, model: OIG-43M updated successfully.
# Document with ID 6697b3b814a5850299849075, model: OIG-moderation updated successfully.
# Document with ID 6697b3b814a5850299849076, model: RedPajama-Data updated successfully.
# Document with ID 6697b3b814a5850299849077, model: Llama-2-7B-32K-Instruct updated successfully.
# Document with ID 6697b3b814a5850299849078, model: RedPajama-Data-v2 updated successfully.
# Document with ID 6697b3b814a5850299849079, model: StripedHyena updated successfully.
# Document with ID 6697b3b814a585029984907a, model: StripedHyena Nous updated successfully.
# Document with ID 6697b3b814a585029984907b, model: MediTron updated successfully.
# Document with ID 6697b3b814a585029984907c, model: XVERSE updated successfully.
# Document with ID 6697b3b814a585029984907d, model: Otter updated successfully.
# Document with ID 6697b3b814a585029984907e, model: EXMODD updated successfully.
# Document with ID 6697b3b814a585029984907f, model: MiniMA updated successfully.
# Document with ID 6697b3b814a5850299849080, model: ChatGLM updated successfully.
# Document with ID 6697b3b814a5850299849081, model: OpenFold updated successfully.
# Document with ID 6697b3b814a5850299849082, model: Ferret updated successfully.
# Document with ID 6697b3b814a5850299849083, model: Guanaco updated successfully.
# Document with ID 6697b3b814a5850299849084, model: Llark updated successfully.
# Document with ID 6697b3b814a5850299849085, model: InternLM updated successfully.
# Document with ID 6697b3b814a5850299849086, model: BioMistral updated successfully.
# Document with ID 6697b3b814a5850299849087, model: Khanmigo updated successfully.
# Document with ID 6697b3b814a5850299849088, model: GAIA-1 updated successfully.
# Document with ID 6697b3b814a5850299849089, model: GreenBit LLaMA updated successfully.
# Document with ID 6697b3b814a585029984908a, model: Ocean-1 updated successfully.
# Document with ID 6697b3b814a585029984908b, model: Aurora-M updated successfully.
# Document with ID 6697b3b814a585029984908c, model: CodeParrot updated successfully.
# Document with ID 6697b3b814a585029984908d, model: Zephyr updated successfully.
# Document with ID 6697b3b814a585029984908e, model: IDEFICS updated successfully.
# Document with ID 6697b3b814a585029984908f, model: OBELICS updated successfully.
# Document with ID 6697b3b814a5850299849090, model: FinGPT updated successfully.
# Document with ID 6697b3b814a5850299849091, model: BLUUMI updated successfully.
# Document with ID 6697b3b814a5850299849092, model: Cosmopedia v0.1 updated successfully.
# Document with ID 6697b3b814a5850299849093, model: Idefics2 updated successfully.
# Document with ID 6697b3b814a5850299849094, model: The Cauldron updated successfully.
# Document with ID 6697b3b814a5850299849095, model: DeepFloyd IF updated successfully.
# Document with ID 6697b3b814a5850299849096, model: StableLM updated successfully.
# Document with ID 6697b3b814a5850299849097, model: Stable Diffusion updated successfully.
# Document with ID 6697b3b814a5850299849098, model: Stable Diffusion XL updated successfully.
# Document with ID 6697b3b814a5850299849099, model: Stable Video Diffusion updated successfully.
# Document with ID 6697b3b814a585029984909a, model: Large Video Dataset updated successfully.
# Document with ID 6697b3b814a585029984909b, model: Sky Replacer updated successfully.
# Document with ID 6697b3b814a585029984909c, model: StableLM 2 updated successfully.
# Document with ID 6697b3b814a585029984909d, model: Stable Cascade updated successfully.
# Document with ID 6697b3b814a585029984909e, model: Stable Video 3D updated successfully.
# Document with ID 6697b3b814a585029984909f, model: Stable Audio 2.0 updated successfully.
# Document with ID 6697b3b814a58502998490a0, model: Reka Flash updated successfully.
# Document with ID 6697b3b814a58502998490a1, model: Reka Core updated successfully.
# Document with ID 6697b3b814a58502998490a2, model: FuseChat updated successfully.
# Document with ID 6697b3b814a58502998490a3, model: MoMo updated successfully.
# Document with ID 6697b3b814a58502998490a4, model: Mistral updated successfully.
# Document with ID 6697b3b814a58502998490a5, model: Mistral Large updated successfully.
# Document with ID 6697b3b814a58502998490a6, model: Le Chat updated successfully.
# Document with ID 6697b3b814a58502998490a7, model: Reexpress One updated successfully.
# Document with ID 6697b3b814a58502998490a8, model: Dolphin 2.2 Yi updated successfully.
# Document with ID 6697b3b814a58502998490a9, model: WizardLM Uncensored updated successfully.
# Document with ID 6697b3b814a58502998490aa, model: DuckAssist updated successfully.
# Document with ID 6697b3b814a58502998490ab, model: Perplexity Ask updated successfully.
# Document with ID 6697b3b814a58502998490ac, model: Bird SQL updated successfully.
# Document with ID 6697b3b814a58502998490ad, model: Perplexity Chat updated successfully.
# Document with ID 6697b3b814a58502998490ae, model: Vulture updated successfully.
# Document with ID 6697b3b814a58502998490af, model: DeciLM updated successfully.
# Document with ID 6697b3b814a58502998490b0, model: The Pile updated successfully.
# Document with ID 6697b3b814a58502998490b1, model: GPT-J updated successfully.
# Document with ID 6697b3b814a58502998490b2, model: GPT-Neo updated successfully.
# Document with ID 6697b3b814a58502998490b3, model: GPT-NeoX updated successfully.
# Document with ID 6697b3b814a58502998490b4, model: GooseAI API updated successfully.
# Document with ID 6697b3b814a58502998490b5, model: VQGAN-CLIP updated successfully.
# Document with ID 6697b3b814a58502998490b6, model: Pythia updated successfully.
# Document with ID 6697b3b814a58502998490b7, model: Llemma updated successfully.
# Document with ID 6697b3b814a58502998490b8, model: Proof Pile 2 updated successfully.
# Document with ID 6697b3b814a58502998490b9, model: Pile-T5 updated successfully.
# Document with ID 6697b3b814a58502998490ba, model: Virtual Volunteer updated successfully.
# Document with ID 6697b3b814a58502998490bb, model: CodeGeeX updated successfully.
# Document with ID 6697b3b814a58502998490bc, model: CogView updated successfully.
# Document with ID 6697b3b814a58502998490bd, model: CogView 2 updated successfully.
# Document with ID 6697b3b814a58502998490be, model: CogVideo updated successfully.
# Document with ID 6697b3b814a58502998490bf, model: GLM-130B updated successfully.
# Document with ID 6697b3b814a58502998490c0, model: CogVLM updated successfully.
# Document with ID 6697b3b814a58502998490c1, model: UltraLM updated successfully.
# Document with ID 6697b3b814a58502998490c2, model: UltraChat updated successfully.
# Document with ID 6697b3b814a58502998490c3, model: PolyCoder updated successfully.
# Document with ID 6697b3b814a58502998490c4, model: Moment updated successfully.
# Document with ID 6697b3b814a58502998490c5, model: OpenAssistant LLaMA 2 updated successfully.
# Document with ID 6697b3b814a58502998490c6, model: Inflection-1 updated successfully.
# Document with ID 6697b3b814a58502998490c7, model: Pi updated successfully.
# Document with ID 6697b3b814a58502998490c8, model: Inflection-2 updated successfully.
# Document with ID 6697b3b814a58502998490c9, model: Inflection-2.5 updated successfully.
# Document with ID 6697b3b814a58502998490ca, model: RWKV World 4 updated successfully.
# Document with ID 6697b3b814a58502998490cb, model: RWKV 4 Pile updated successfully.
# Document with ID 6697b3b814a58502998490cc, model: RWKV World 5 updated successfully.
# Document with ID 6697b3b814a58502998490cd, model: ERNIE 3.0 Titan updated successfully.
# Document with ID 6697b3b814a58502998490ce, model: ERNIE-ViLG updated successfully.
# Document with ID 6697b3b814a58502998490cf, model: ERNIE-ViLG 2.0 updated successfully.
# Document with ID 6697b3b814a58502998490d0, model: ERNIE 4.0 updated successfully.
# Document with ID 6697b3b814a58502998490d1, model: Q-Chat updated successfully.
# Document with ID 6697b3b814a58502998490d2, model: Bedrock updated successfully.
# Document with ID 6697b3b814a58502998490d3, model: FalconLite2 updated successfully.
# Document with ID 6697b3b814a58502998490d4, model: Chronos updated successfully.
# Document with ID 6697b3b814a58502998490d5, model: Prism updated successfully.
# Document with ID 6697b3b814a58502998490d6, model: InternVideo updated successfully.
# Document with ID 6697b3b814a58502998490d7, model: Lego-MT updated successfully.
# Document with ID 6697b3b814a58502998490d8, model: MathCoder updated successfully.
# Document with ID 6697b3b814a58502998490d9, model: InternLM updated successfully.
# Document with ID 6697b3b814a58502998490da, model: InternVideo2 updated successfully.
# Document with ID 6697b3b814a58502998490db, model: CosmicMan updated successfully.
# Document with ID 6697b3b814a58502998490dc, model: CosmicMan-HQ 1.0 updated successfully.
# Document with ID 6697b3b814a58502998490dd, model: Nucleus updated successfully.
# Document with ID 6697b3b814a58502998490de, model: Devin updated successfully.
# Document with ID 6697b3b814a58502998490df, model: Konan LLM updated successfully.
# Document with ID 6697b3b814a58502998490e0, model: LinkedIn updated successfully.
# Document with ID 6697b3b814a58502998490e1, model: Character updated successfully.
# Document with ID 6697b3b814a58502998490e2, model: Open X-Embodiment dataset updated successfully.
# Document with ID 6697b3b814a58502998490e3, model: RT-1-X updated successfully.
# Document with ID 6697b3b814a58502998490e4, model: RT-2-X updated successfully.
# Document with ID 6697b3b814a58502998490e5, model: Taiyi Diffusion XL updated successfully.
# Document with ID 6697b3b814a58502998490e6, model: Pegasus-1 updated successfully.
# Document with ID 6697b3b814a58502998490e7, model: Marengo 2.6 updated successfully.
# Document with ID 6697b3b814a58502998490e8, model: GodziLLa 2 updated successfully.
# Document with ID 6697b3b814a58502998490e9, model: BiomedGPT updated successfully.
# Document with ID 6697b3b814a58502998490ea, model: MM1 updated successfully.
# Document with ID 6697b3b814a58502998490eb, model: OpenELM updated successfully.
# Document with ID 6697b3b814a58502998490ec, model: StarCoder updated successfully.
# Document with ID 6697b3b814a58502998490ed, model: SantaCoder updated successfully.
# Document with ID 6697b3b814a58502998490ee, model: The Stack updated successfully.
# Document with ID 6697b3b814a58502998490ef, model: StarCoder2-15B updated successfully.
# Document with ID 6697b3b814a58502998490f0, model: StarCoder2-7B updated successfully.
# Document with ID 6697b3b814a58502998490f1, model: StarCoder2-3B updated successfully.
# Document with ID 6697b3b814a58502998490f2, model: h2oGPT updated successfully.
# Document with ID 6697b3b814a58502998490f3, model: H2O Danube updated successfully.
# Document with ID 6697b3b814a58502998490f4, model: ARES updated successfully.
# Document with ID 6697b3b814a58502998490f5, model: C4 updated successfully.
# Document with ID 6697b3b814a58502998490f6, model: Internal Google BERT dataset updated successfully.
# Document with ID 6697b3b814a58502998490f7, model: Conceptual Captions updated successfully.
# Document with ID 6697b3b814a58502998490f8, model: Conceptual 12M updated successfully.
# Document with ID 6697b3b814a58502998490f9, model: T5 updated successfully.
# Document with ID 6697b3b814a58502998490fa, model: Internal Google BERT updated successfully.
# Document with ID 6697b3b814a58502998490fb, model: Google Search updated successfully.
# Document with ID 6697b3b814a58502998490fc, model: Infiniset updated successfully.
# Document with ID 6697b3b814a58502998490fd, model: LaMDA updated successfully.
# Document with ID 6697b3b814a58502998490fe, model: PaLM dataset updated successfully.
# Document with ID 6697b3b814a58502998490ff, model: Flan-T5 updated successfully.
# Document with ID 6697b3b814a5850299849100, model: UL2 updated successfully.
# Document with ID 6697b3b814a5850299849101, model: Parti updated successfully.
# Document with ID 6697b3b814a5850299849102, model: Imagen updated successfully.
# Document with ID 6697b3b814a5850299849103, model: VATT updated successfully.
# Document with ID 6697b3b814a5850299849104, model: PaLM updated successfully.
# Document with ID 6697b3b814a5850299849105, model: PaLM API updated successfully.
# Document with ID 6697b3b814a5850299849106, model: Med-PaLM updated successfully.
# Document with ID 6697b3b814a5850299849107, model: Med-PaLM Multimodal updated successfully.
# Document with ID 6697b3b814a5850299849108, model: MultiMedQA updated successfully.
# Document with ID 6697b3b814a5850299849109, model: Flan-PaLM updated successfully.
# Document with ID 6697b3b814a585029984910a, model: Flan-U-PaLM updated successfully.
# Document with ID 6697b3b814a585029984910b, model: Muffin updated successfully.
# Document with ID 6697b3b814a585029984910c, model: U-PaLM updated successfully.
# Document with ID 6697b3b814a585029984910d, model: PaLM-SayCan updated successfully.
# Document with ID 6697b3b814a585029984910e, model: GLaM updated successfully.
# Document with ID 6697b3b814a585029984910f, model: GLaM Web dataset updated successfully.
# Document with ID 6697b3b814a5850299849110, model: GLaM Conversations dataset updated successfully.
# Document with ID 6697b3b814a5850299849111, model: GLaM Forums dataset updated successfully.
# Document with ID 6697b3b814a5850299849112, model: GLaM News dataset updated successfully.
# Document with ID 6697b3b814a5850299849113, model: MUM updated successfully.
# Document with ID 6697b3b814a5850299849114, model: MUM dataset updated successfully.
# Document with ID 6697b3b814a5850299849115, model: Phenaki updated successfully.
# Document with ID 6697b3b814a5850299849116, model: Phenaki Video-Text Corpus updated successfully.
# Document with ID 6697b3b814a5850299849117, model: Flan-UL2 updated successfully.
# Document with ID 6697b3b814a5850299849118, model: Flan Collection updated successfully.
# Document with ID 6697b3b814a5850299849119, model: MusicLM updated successfully.
# Document with ID 6697b3b814a585029984911a, model: SoundStream updated successfully.
# Document with ID 6697b3b814a585029984911b, model: w2v-BERT updated successfully.
# Document with ID 6697b3b814a585029984911c, model: MuLan updated successfully.
# Document with ID 6697b3b814a585029984911d, model: MuLan dataset updated successfully.
# Document with ID 6697b3b814a585029984911e, model: MusicLM dataset updated successfully.
# Document with ID 6697b3b814a585029984911f, model: MusicLM semantic model updated successfully.
# Document with ID 6697b3b814a5850299849120, model: MusicLM acoustic model updated successfully.
# Document with ID 6697b3b814a5850299849121, model: Noise2Music updated successfully.
# Document with ID 6697b3b814a5850299849122, model: LaMDA-LF updated successfully.
# Document with ID 6697b3b814a5850299849123, model: Rater-LF updated successfully.
# Document with ID 6697b3b814a5850299849124, model: Rater-SF updated successfully.
# Document with ID 6697b3b814a5850299849125, model: Noise2Music pseudolabeler updated successfully.
# Document with ID 6697b3b814a5850299849126, model: Noise2Music audio dataset updated successfully.
# Document with ID 6697b3b814a5850299849127, model: Noise2Music pseudolabel dataset updated successfully.
# Document with ID 6697b3b814a5850299849128, model: AI Test Kitchen updated successfully.
# Document with ID 6697b3b814a5850299849129, model: Bard updated successfully.
# Document with ID 6697b3b814a585029984912a, model: Minerva updated successfully.
# Document with ID 6697b3b814a585029984912b, model: Minerva Math Web Pages dataset updated successfully.
# Document with ID 6697b3b814a585029984912c, model: USM updated successfully.
# Document with ID 6697b3b814a585029984912d, model: YouTube updated successfully.
# Document with ID 6697b3b814a585029984912e, model: PaLM-E updated successfully.
# Document with ID 6697b3b814a585029984912f, model: ViT-22B updated successfully.
# Document with ID 6697b3b814a5850299849130, model: AudioLM updated successfully.
# Document with ID 6697b3b814a5850299849131, model: PaLI updated successfully.
# Document with ID 6697b3b814a5850299849132, model: ViT-e updated successfully.
# Document with ID 6697b3b814a5850299849133, model: WebLI updated successfully.
# Document with ID 6697b3b814a5850299849134, model: Vid2Seq updated successfully.
# Document with ID 6697b3b814a5850299849135, model: Google Joint SLM updated successfully.
# Document with ID 6697b3b814a5850299849136, model: PaLM 2 updated successfully.
# Document with ID 6697b3b814a5850299849137, model: MedLM updated successfully.
# Document with ID 6697b3b814a5850299849138, model: Gemini updated successfully.
# Document with ID 6697b3b814a5850299849139, model: TimesFM updated successfully.
# Document with ID 6697b3b814a585029984913a, model: Gemma updated successfully.
# Document with ID 6697b3b814a585029984913b, model: Med-Gemini updated successfully.
# Document with ID 6697b3b814a585029984913c, model: HyperCLOVA updated successfully.
# Document with ID 6697b3b814a585029984913d, model: HyperCLOVA X updated successfully.
# Document with ID 6697b3b814a585029984913e, model: Crisis Contact Simulator updated successfully.
# Document with ID 6697b3b814a585029984913f, model: Ask Instacart updated successfully.
# Document with ID 6697b3b814a5850299849140, model: Firefly Image 2 updated successfully.
# Document with ID 6697b3b814a5850299849141, model: Firefly Vector updated successfully.
# Document with ID 6697b3b814a5850299849142, model: Firefly Design updated successfully.
# Document with ID 6697b3b814a5850299849143, model: Firefly updated successfully.
# Document with ID 6697b3b814a5850299849144, model: CulturaX updated successfully.
# Document with ID 6697b3b814a5850299849145, model: GenSLM updated successfully.
# Document with ID 6697b3b814a5850299849146, model: Moonhub Recruiter updated successfully.
# Document with ID 6697b3b814a5850299849147, model: Skywork updated successfully.
# Document with ID 6697b3b814a5850299849148, model: COYO-700M updated successfully.
# Document with ID 6697b3b814a5850299849149, model: Kotoba Speech updated successfully.
# Document with ID 6697b3b814a585029984914a, model: Shop Assistant updated successfully.
# Document with ID 6697b3b814a585029984914b, model: GPT-3 dataset updated successfully.
# Document with ID 6697b3b814a585029984914c, model: HumanEval updated successfully.
# Document with ID 6697b3b814a585029984914d, model: Codex dataset updated successfully.
# Document with ID 6697b3b814a585029984914e, model: CLIP dataset updated successfully.
# Document with ID 6697b3b814a585029984914f, model: DALL·E dataset updated successfully.
# Document with ID 6697b3b814a5850299849150, model: Whisper dataset updated successfully.
# Document with ID 6697b3b814a5850299849151, model: WebText updated successfully.
# Document with ID 6697b3b814a5850299849152, model: GPT-2 updated successfully.
# Document with ID 6697b3b814a5850299849153, model: GPT-3 updated successfully.
# Document with ID 6697b3b814a5850299849154, model: Codex updated successfully.
# Document with ID 6697b3b814a5850299849155, model: InstructGPT updated successfully.
# Document with ID 6697b3b814a5850299849156, model: Whisper updated successfully.
# Document with ID 6697b3b814a5850299849157, model: CLIP updated successfully.
# Document with ID 6697b3b814a5850299849158, model: DALL·E updated successfully.
# Document with ID 6697b3b814a5850299849159, model: Jukebox updated successfully.
# Document with ID 6697b3b814a585029984915a, model: DALL·E 2 updated successfully.
# Document with ID 6697b3b814a585029984915b, model: OpenAI API updated successfully.
# Document with ID 6697b3b814a585029984915c, model: VPT updated successfully.
# Document with ID 6697b3b814a585029984915d, model: web_clean updated successfully.
# Document with ID 6697b3b814a585029984915e, model: ChatGPT updated successfully.
# Document with ID 6697b3b814a585029984915f, model: gpt-3.5-turbo updated successfully.
# Document with ID 6697b3b814a5850299849160, model: GPT-4 Turbo updated successfully.
# Document with ID 6697b3b814a5850299849161, model: gpt-3.5-turbo dataset updated successfully.
# Document with ID 6697b3b814a5850299849162, model: code-davinci-002 dataset updated successfully.
# Document with ID 6697b3b814a5850299849163, model: code-davinci-002 updated successfully.
# Document with ID 6697b3b814a5850299849164, model: text-davinci-002 updated successfully.
# Document with ID 6697b3b814a5850299849165, model: text-davinci-003 updated successfully.
# Document with ID 6697b3b814a5850299849166, model: Whisper API updated successfully.
# Document with ID 6697b3b814a5850299849167, model: ChatGPT API updated successfully.
# Document with ID 6697b3b814a5850299849168, model: OpenAI Moderation API updated successfully.
# Document with ID 6697b3b814a5850299849169, model: OpenAI toxicity classifier updated successfully.
# Document with ID 6697b3b814a585029984916a, model: OpenAI toxicity dataset updated successfully.
# Document with ID 6697b3b814a585029984916b, model: Sage API updated successfully.
# Document with ID 6697b3b814a585029984916c, model: Dragonfly API updated successfully.
# Document with ID 6697b3b814a585029984916d, model: Sage updated successfully.
# Document with ID 6697b3b814a585029984916e, model: Dragonfly updated successfully.
# Document with ID 6697b3b814a585029984916f, model: ChatGPT for Slack updated successfully.
# Document with ID 6697b3b814a5850299849170, model: GPT-4 updated successfully.
# Document with ID 6697b3b814a5850299849171, model: GPT-4 API updated successfully.
# Document with ID 6697b3b814a5850299849172, model: ChatGPT Enterprise updated successfully.
# Document with ID 6697b3b814a5850299849173, model: DALL·E 3 updated successfully.
# Document with ID 6697b3b814a5850299849174, model: Sora updated successfully.
# Document with ID 6697b3b814a5850299849175, model: Ideogram 1.0 updated successfully.
# Document with ID 6697b3b814a5850299849176, model: FinPile updated successfully.
# Document with ID 6697b3b814a5850299849177, model: BloombergGPT updated successfully.
# Document with ID 6697b3b814a5850299849178, model: Common Corpus updated successfully.
# Document with ID 6697b3b814a5850299849179, model: Cformers updated successfully.
# Document with ID 6697b3b814a585029984917a, model: Platypus updated successfully.
# Document with ID 6697b3b814a585029984917b, model: UFOGen updated successfully.
# Document with ID 6697b3b814a585029984917c, model: Nextdoor Assistant updated successfully.
# Document with ID 6697b3b814a585029984917d, model: You dataset updated successfully.
# Document with ID 6697b3b814a585029984917e, model: You model updated successfully.
# Document with ID 6697b3b814a585029984917f, model: You Search updated successfully.
# Document with ID 6697b3b814a5850299849180, model: SBU Captions updated successfully.
# Document with ID 6697b3b814a5850299849181, model: MassiveText updated successfully.
# Document with ID 6697b3b814a5850299849182, model: M3W updated successfully.
# Document with ID 6697b3b814a5850299849183, model: Gato dataset updated successfully.
# Document with ID 6697b3b814a5850299849184, model: AlphaFold2 updated successfully.
# Document with ID 6697b3b814a5850299849185, model: Flamingo updated successfully.
# Document with ID 6697b3b814a5850299849186, model: AlphaCode updated successfully.
# Document with ID 6697b3b814a5850299849187, model: Gopher updated successfully.
# Document with ID 6697b3b814a5850299849188, model: Chinchilla updated successfully.
# Document with ID 6697b3b814a5850299849189, model: Gato updated successfully.
# Document with ID 6697b3b814a585029984918a, model: Sparrow updated successfully.
# Document with ID 6697b3b814a585029984918b, model: RETRO updated successfully.
# Document with ID 6697b3b814a585029984918c, model: Sparrow Rule reward model updated successfully.
# Document with ID 6697b3b814a585029984918d, model: Sparrow Preference reward model updated successfully.
# Document with ID 6697b3b814a585029984918e, model: Sparrow adversarial probing dataset updated successfully.
# Document with ID 6697b3b814a585029984918f, model: Sparrow response preference dataset updated successfully.
# Document with ID 6697b3b814a5850299849190, model: GopherCite updated successfully.
# Document with ID 6697b3b814a5850299849191, model: GopherCite reward model updated successfully.
# Document with ID 6697b3b814a5850299849192, model: GopherCite Preference dataset updated successfully.
# Document with ID 6697b3b814a5850299849193, model: Dramatron updated successfully.
# Document with ID 6697b3b814a5850299849194, model: RT-2 updated successfully.
# Document with ID 6697b3b814a5850299849195, model: Lyria updated successfully.
# Document with ID 6697b3b814a5850299849196, model: Genie updated successfully.
# Document with ID 6697b3b814a5850299849197, model: YT-Temporal-1B updated successfully.
# Document with ID 6697b3b814a5850299849198, model: WebVid-10M updated successfully.
# Document with ID 6697b3b814a5850299849199, model: WebVid-2M updated successfully.
# Document with ID 6697b3b814a585029984919a, model: Sana updated successfully.
# Document with ID 6697b3b814a585029984919b, model: NaturalInstructions-v2 updated successfully.
# Document with ID 6697b3b814a585029984919c, model: SODA updated successfully.
# Document with ID 6697b3b814a585029984919d, model: Multimodal C4 updated successfully.
# Document with ID 6697b3b814a585029984919e, model: COSMO updated successfully.
# Document with ID 6697b3b814a585029984919f, model: Dolma updated successfully.
# Document with ID 6697b3b814a58502998491a0, model: Tulu-V2-mix updated successfully.
# Document with ID 6697b3b814a58502998491a1, model: Tulu 2 updated successfully.
# Document with ID 6697b3b814a58502998491a2, model: Tulu 2 DPO updated successfully.
# Document with ID 6697b3b814a58502998491a3, model: Code Tulu 2 updated successfully.
# Document with ID 6697b3b814a58502998491a4, model: OLMo updated successfully.
# Document with ID 6697b3b814a58502998491a5, model: MADLAD-400 updated successfully.
# Document with ID 6697b3b814a58502998491a6, model: VARCO-LLM updated successfully.
# Document with ID 6697b3b814a58502998491a7, model: UnderwriteGPT updated successfully.
# Document with ID 6697b3b814a58502998491a8, model: Cerebras-GPT updated successfully.
# Document with ID 6697b3b814a58502998491a9, model: Jais updated successfully.
# Document with ID 6697b3b814a58502998491aa, model: Jais Chat updated successfully.
# Document with ID 6697b3b814a58502998491ab, model: Bittensor Language Model updated successfully.
# Document with ID 6697b3b814a58502998491ac, model: SlimPajama updated successfully.
# Document with ID 6697b3b814a58502998491ad, model: CodeGen updated successfully.
# Document with ID 6697b3b814a58502998491ae, model: BLIP updated successfully.
# Document with ID 6697b3b814a58502998491af, model: LAION-115M updated successfully.
# Document with ID 6697b3b814a58502998491b0, model: EinsteinGPT updated successfully.
# Document with ID 6697b3b814a58502998491b1, model: BLIP-2 updated successfully.
# Document with ID 6697b3b814a58502998491b2, model: Moirai updated successfully.
# Document with ID 6697b3b814a58502998491b3, model: LOTSA updated successfully.
# Document with ID 6697b3b814a58502998491b4, model: Neeva dataset updated successfully.
# Document with ID 6697b3b814a58502998491b5, model: Neeva model updated successfully.
# Document with ID 6697b3b814a58502998491b6, model: NeevaAI updated successfully.
# Document with ID 6697b3b814a58502998491b7, model: Jurassic-1 dataset updated successfully.
# Document with ID 6697b3b814a58502998491b8, model: Jurassic-1 Instruct dataset updated successfully.
# Document with ID 6697b3b814a58502998491b9, model: Jurassic-1 updated successfully.
# Document with ID 6697b3b814a58502998491ba, model: Jurassic-1 Instruct updated successfully.
# Document with ID 6697b3b814a58502998491bb, model: Jurassic-2 updated successfully.
# Document with ID 6697b3b814a58502998491bc, model: AI21 Playground updated successfully.
# Document with ID 6697b3b814a58502998491bd, model: AI21 Paraphrase API updated successfully.
# Document with ID 6697b3b814a58502998491be, model: AI21 Summarization API updated successfully.
# Document with ID 6697b3b814a58502998491bf, model: Wordtune updated successfully.
# Document with ID 6697b3b814a58502998491c0, model: Wordtune Read updated successfully.
# Document with ID 6697b3b814a58502998491c1, model: Jamba updated successfully.
# Document with ID 6697b3b814a58502998491c2, model: MPT updated successfully.
# Document with ID 6697b3b814a58502998491c3, model: CommonCanvas updated successfully.
# Document with ID 6697b3b814a58502998491c4, model: CommonCatalog updated successfully.
# Document with ID 6697b3b814a58502998491c5, model: AI Dungeon updated successfully.
# Document with ID 6697b3b814a58502998491c6, model: Conformer-1 dataset updated successfully.
# Document with ID 6697b3b814a58502998491c7, model: Conformer-1 updated successfully.
# Document with ID 6697b3b814a58502998491c8, model: AssemblyAI updated successfully.
# Document with ID 6697b3b814a58502998491c9, model: Conformer-1 API updated successfully.
# Document with ID 6697b3b814a58502998491ca, model: Xwin-LM updated successfully.
# Document with ID 6697b3b814a58502998491cb, model: JARVIS-1 updated successfully.
# Document with ID 6697b3b814a58502998491cc, model: MAmmoTH updated successfully.
# Document with ID 6697b3b814a58502998491cd, model: A.X updated successfully.
# Document with ID 6697b3b814a58502998491ce, model: Yi updated successfully.
# Document with ID 6697b3b814a58502998491cf, model: Yi-VL updated successfully.
# Document with ID 6697b3b814a58502998491d0, model: HowTo100M updated successfully.
# Document with ID 6697b3b814a58502998491d1, model: Lemur updated successfully.
# Document with ID 6697b3b814a58502998491d2, model: Lemur-Chat updated successfully.
# Document with ID 6697b3b814a58502998491d3, model: ACT-1 updated successfully.
# Document with ID 6697b3b814a58502998491d4, model: Persimmon updated successfully.
# Document with ID 6697b3b814a58502998491d5, model: Fuyu updated successfully.
# Document with ID 6697b3b814a58502998491d6, model: Fuyu Heavy updated successfully.
# Document with ID 6697b3b814a58502998491d7, model: CPM Bee updated successfully.
# Document with ID 6697b3b814a58502998491d8, model: UltraFeedback updated successfully.
# Document with ID 6697b3b814a58502998491d9, model: MiniCPM updated successfully.
# Document with ID 6697b3b814a58502998491da, model: Eurus updated successfully.
# Document with ID 6697b3b814a58502998491db, model: 10k_prompts_ranked updated successfully.
# Document with ID 6697b3b814a58502998491dc, model: ESM-2 updated successfully.
# Document with ID 6697b3b814a58502998491dd, model: PMD updated successfully.
# Document with ID 6697b3b814a58502998491de, model: FLAVA updated successfully.
# Document with ID 6697b3b814a58502998491df, model: The Galactica Corpus updated successfully.
# Document with ID 6697b3b814a58502998491e0, model: Galactica updated successfully.
# Document with ID 6697b3b814a58502998491e1, model: InCoder updated successfully.
# Document with ID 6697b3b814a58502998491e2, model: OPT updated successfully.
# Document with ID 6697b3b814a58502998491e3, model: Make-A-Video dataset updated successfully.
# Document with ID 6697b3b814a58502998491e4, model: Make-A-Video updated successfully.
# Document with ID 6697b3b814a58502998491e5, model: LLaMA updated successfully.
# Document with ID 6697b3b814a58502998491e6, model: Llama 2 updated successfully.
# Document with ID 6697b3b814a58502998491e7, model: OPT-IML updated successfully.
# Document with ID 6697b3b814a58502998491e8, model: SA-1B updated successfully.
# Document with ID 6697b3b814a58502998491e9, model: SAM updated successfully.
# Document with ID 6697b3b814a58502998491ea, model: Voicebox updated successfully.
# Document with ID 6697b3b814a58502998491eb, model: PEER updated successfully.
# Document with ID 6697b3b814a58502998491ec, model: MusicGen updated successfully.
# Document with ID 6697b3b814a58502998491ed, model: AudioGen updated successfully.
# Document with ID 6697b3b814a58502998491ee, model: Emu updated successfully.
# Document with ID 6697b3b814a58502998491ef, model: Code LLaMA updated successfully.
# Document with ID 6697b3b814a58502998491f0, model: Emu Video updated successfully.
# Document with ID 6697b3b814a58502998491f1, model: Emu Edit updated successfully.
# Document with ID 6697b3b814a58502998491f2, model: MetaCLIP updated successfully.
# Document with ID 6697b3b814a58502998491f3, model: Llama 3 updated successfully.
# Document with ID 6697b3b814a58502998491f4, model: HyperWrite updated successfully.
# Document with ID 6697b3b814a58502998491f5, model: Midm updated successfully.
# Document with ID 6697b3b814a58502998491f6, model: Anthropic Helpfulness dataset updated successfully.
# Document with ID 6697b3b814a58502998491f7, model: Anthropic Harmlessness dataset updated successfully.
# Document with ID 6697b3b814a58502998491f8, model: Anthropic RLHF models updated successfully.
# Document with ID 6697b3b814a58502998491f9, model: Anthropic Human Feedback Interface updated successfully.
# Document with ID 6697b3b814a58502998491fa, model: Anthropic API updated successfully.
# Document with ID 6697b3b814a58502998491fb, model: Claude updated successfully.
# Document with ID 6697b3b814a58502998491fc, model: Claude Instant updated successfully.
# Document with ID 6697b3b814a58502998491fd, model: Claude 2 updated successfully.
# Document with ID 6697b3b814a58502998491fe, model: Claude 2.1 updated successfully.
# Document with ID 6697b3b814a58502998491ff, model: Claude for Sheets updated successfully.
# Document with ID 6697b3b814a5850299849200, model: Claude 3 updated successfully.
# Document with ID 6697b3b814a5850299849201, model: ROOTS updated successfully.
# Document with ID 6697b3b814a5850299849202, model: P3 updated successfully.
# Document with ID 6697b3b814a5850299849203, model: xP3 updated successfully.
# Document with ID 6697b3b814a5850299849204, model: T0++ updated successfully.
# Document with ID 6697b3b814a5850299849205, model: BLOOM updated successfully.
# Document with ID 6697b3b814a5850299849206, model: mT0 updated successfully.
# Document with ID 6697b3b814a5850299849207, model: BLOOMZ updated successfully.
# Document with ID 6697b3b814a5850299849208, model: CausalLM updated successfully.
# Document with ID 6697b3b814a5850299849209, model: Bain Chat updated successfully.
# Document with ID 6697b3b814a585029984920a, model: SauerkrautLM updated successfully.
# Document with ID 6697b3b814a585029984920b, model: Transformify Automate updated successfully.
# Document with ID 6697b3b814a585029984920c, model: Palmyra updated successfully.
# Document with ID 6697b3b814a585029984920d, model: Camel updated successfully.
# Document with ID 6697b3b814a585029984920e, model: Dolly updated successfully.
# Document with ID 6697b3b814a585029984920f, model: DBRX updated successfully.
# Document with ID 6697b3b814a5850299849210, model: Vicuna updated successfully.
# Document with ID 6697b3b814a5850299849211, model: EXAONE 2.0 updated successfully.
# Document with ID 6697b3b814a5850299849212, model: RakutenAI updated successfully.
# Document with ID 6697b3b814a5850299849213, model: OpenBA updated successfully.
# Document with ID 6697b3b814a5850299849214, model: AI DJ updated successfully.
# Document with ID 6697b3b814a5850299849215, model: Koala updated successfully.
# Document with ID 6697b3b814a5850299849216, model: Gorilla updated successfully.
# Document with ID 6697b3b814a5850299849217, model: OpenLLaMA updated successfully.
# Document with ID 6697b3b814a5850299849218, model: SaiLY updated successfully.
# Document with ID 6697b3b814a5850299849219, model: Poe updated successfully.
# Document with ID 6697b3b814a585029984921a, model: Notion AI updated successfully.
# Document with ID 6697b3b814a585029984921b, model: Deepseek updated successfully.
# Document with ID 6697b3b814a585029984921c, model: Deepseek Chat updated successfully.
# Document with ID 6697b3b814a585029984921d, model: Deepseek Coder updated successfully.
# Document with ID 6697b3b814a585029984921e, model: Starling updated successfully.
# Document with ID 6697b3b814a585029984921f, model: Falcon-40B updated successfully.
# Document with ID 6697b3b814a5850299849220, model: RefinedWeb updated successfully.
# Document with ID 6697b3b814a5850299849221, model: Falcon-180B updated successfully.
# Document with ID 6697b3b814a5850299849222, model: My AI for Snapchat updated successfully.
# Document with ID 6697b3b814a5850299849223, model: Brex Chat updated successfully.
# Document with ID 6697b3b814a5850299849224, model: LAION-400M updated successfully.
# Document with ID 6697b3b814a5850299849225, model: LAION-5B updated successfully.
# Document with ID 6697b3b814a5850299849226, model: LAION-2B-en updated successfully.
# Document with ID 6697b3b814a5850299849227, model: OpenFlamingo updated successfully.
# Document with ID 6697b3b814a5850299849228, model: SALMONN updated successfully.
# Document with ID 6697b3b814a5850299849229, model: SDXL-Lightning updated successfully.
# Document with ID 6697b3b814a585029984922a, model: VLMo updated successfully.
# Document with ID 6697b3b814a585029984922b, model: T-ULRv5 updated successfully.
# Document with ID 6697b3b814a585029984922c, model: Turing NLR-v5 updated successfully.
# Document with ID 6697b3b814a585029984922d, model: Megatron-Turing NLG updated successfully.
# Document with ID 6697b3b814a585029984922e, model: VALL-E updated successfully.
# Document with ID 6697b3b814a585029984922f, model: GitHub CoPilot updated successfully.
# Document with ID 6697b3b814a5850299849230, model: BioGPT updated successfully.
# Document with ID 6697b3b814a5850299849231, model: Bing Search updated successfully.
# Document with ID 6697b3b814a5850299849232, model: KOSMOS-1 updated successfully.
# Document with ID 6697b3b814a5850299849233, model: Prometheus updated successfully.
# Document with ID 6697b3b814a5850299849234, model: Florence updated successfully.
# Document with ID 6697b3b814a5850299849235, model: FLD-900M updated successfully.
# Document with ID 6697b3b814a5850299849236, model: Azure Cognitive Services for Vision updated successfully.
# Document with ID 6697b3b814a5850299849237, model: VisualChatGPT updated successfully.
# Document with ID 6697b3b814a5850299849238, model: Microsoft 365 Copilot updated successfully.
# Document with ID 6697b3b814a5850299849239, model: Microsoft Business Chat updated successfully.
# Document with ID 6697b3b814a585029984923a, model: Microsoft Excel updated successfully.
# Document with ID 6697b3b814a585029984923b, model: Microsoft Outlook updated successfully.
# Document with ID 6697b3b814a585029984923c, model: Microsoft Power Platform updated successfully.
# Document with ID 6697b3b814a585029984923d, model: Microsoft PowerPoint updated successfully.
# Document with ID 6697b3b814a585029984923e, model: Microsoft Teams updated successfully.
# Document with ID 6697b3b814a585029984923f, model: Microsoft Word updated successfully.
# Document with ID 6697b3b814a5850299849240, model: Microsoft Inside Look updated successfully.
# Document with ID 6697b3b814a5850299849241, model: Microsoft Suggested Replies updated successfully.
# Document with ID 6697b3b814a5850299849242, model: Microsoft Security Copilot updated successfully.
# Document with ID 6697b3b814a5850299849243, model: UniLM updated successfully.
# Document with ID 6697b3b814a5850299849244, model: Docugami updated successfully.
# Document with ID 6697b3b814a5850299849245, model: BEiT-3 updated successfully.
# Document with ID 6697b3b814a5850299849246, model: WizardLM updated successfully.
# Document with ID 6697b3b814a5850299849247, model: WizardCoder updated successfully.
# Document with ID 6697b3b814a5850299849248, model: Florence-2 updated successfully.
# Document with ID 6697b3b814a5850299849249, model: FLD-5B updated successfully.
# Document with ID 6697b3b814a585029984924a, model: OpenOrca updated successfully.
# Document with ID 6697b3b814a585029984924b, model: LlongOrca updated successfully.
# Document with ID 6697b3b814a585029984924c, model: Phi-1.5 updated successfully.
# Document with ID 6697b3b814a585029984924d, model: Orca 2 updated successfully.
# Document with ID 6697b3b814a585029984924e, model: Phi-3 Mini updated successfully.
# Document with ID 6697b3b814a585029984924f, model: TigerBot updated successfully.
# Document with ID 6697b3b814a5850299849250, model: coheretext updated successfully.
# Document with ID 6697b3b814a5850299849251, model: Cohere Base updated successfully.
# Document with ID 6697b3b814a5850299849252, model: Cohere Command updated successfully.
# Document with ID 6697b3b814a5850299849253, model: Cohere Embed (English) updated successfully.
# Document with ID 6697b3b814a5850299849254, model: Cohere Embed (Multilingual) updated successfully.
# Document with ID 6697b3b814a5850299849255, model: Cohere API updated successfully.
# Document with ID 6697b3b814a5850299849256, model: Cohere Generate Endpoint updated successfully.
# Document with ID 6697b3b814a5850299849257, model: Cohere Embed Endpoint updated successfully.
# Document with ID 6697b3b814a5850299849258, model: Cohere Classify Endpoint updated successfully.
# Document with ID 6697b3b814a5850299849259, model: Cohere Summarize Endpoint updated successfully.
# Document with ID 6697b3b814a585029984925a, model: Cohere Embedv3 (English) updated successfully.
# Document with ID 6697b3b814a585029984925b, model: Aya updated successfully.
# Document with ID 6697b3b814a585029984925c, model: Command-R updated successfully.
# Document with ID 6697b3b814a585029984925d, model: Aya Dataset updated successfully.
# Document with ID 6697b3b814a585029984925e, model: Rerank 3 updated successfully.
# Document with ID 6697b3b814a585029984925f, model: Grok-1 updated successfully.
# Document with ID 6697b3b814a5850299849260, model: Grok-1.5V updated successfully.
# Document with ID 6697b3b814a5850299849261, model: Speak updated successfully.
# Document with ID 6697b3b814a5850299849262, model: OceanGPT updated successfully.
# Document with ID 6697b3b814a5850299849263, model: BioMedLM updated successfully.
# Document with ID 6697b3b814a5850299849264, model: RoentGen updated successfully.
# Document with ID 6697b3b814a5850299849265, model: CORGI updated successfully.
# Document with ID 6697b3b814a5850299849266, model: Alpaca dataset updated successfully.
# Document with ID 6697b3b814a5850299849267, model: Alpaca updated successfully.
# Document with ID 6697b3b814a5850299849268, model: AutoMathText updated successfully.
# Document with ID 6697b3b814a5850299849269, model: Nous Hermes 2 updated successfully.
# Document with ID 6697b3b814a585029984926a, model: YaRN LLaMA 2 updated successfully.
# Document with ID 6697b3b814a585029984926b, model: Nous Capybara updated successfully.
# Document with ID 6697b3b814a585029984926c, model: YaRN Mistral updated successfully.
# Document with ID 6697b3b814a585029984926d, model: OpenHermes 2.5 Mistral updated successfully.
# Document with ID 6697b3b814a585029984926e, model: Hermes 2 Pro-Mistral updated successfully.
# Document with ID 6697b3b814a585029984926f, model: Genstruct updated successfully.
# Document with ID 6697b3b814a5850299849270, model: Megatron-LM updated successfully.
# Document with ID 6697b3b814a5850299849271, model: MineDojo updated successfully.
# Document with ID 6697b3b814a5850299849272, model: VIMA dataset updated successfully.
# Document with ID 6697b3b814a5850299849273, model: VIMA updated successfully.
# Document with ID 6697b3b814a5850299849274, model: Nemotron 4 updated successfully.
# Document with ID 6697b3b814a5850299849275, model: BigTrans updated successfully.
# Document with ID 6697b3b814a5850299849276, model: YAYI 2 updated successfully.
# Document with ID 6697b3b814a5850299849277, model: YaLM updated successfully.
# Document with ID 6697b3b814a5850299849278, model: Yandex Search updated successfully.
# Document with ID 6697b3b814a5850299849279, model: Continue updated successfully.
# Document with ID 6697b3b814a585029984927a, model: GOAT updated successfully.
# Document with ID 6697b3b814a585029984927b, model: OpenMoE updated successfully.
# Document with ID 6697b3b814a585029984927c, model: Baichuan 2 updated successfully.
# Document with ID 6697b3b814a585029984927d, model: Wu Dao dataset updated successfully.
# Document with ID 6697b3b814a585029984927e, model: Wu Dao 2.0 updated successfully.
# Document with ID 6697b3b814a585029984927f, model: JudgeLM updated successfully.
# Document with ID 6697b3b814a5850299849280, model: JudgeLM Dataset updated successfully.
# Document with ID 6697b3b814a5850299849281, model: SegMamba updated successfully.
# Document with ID 6697b3b814a5850299849282, model: BGE M3 Embedding updated successfully.
# Document with ID 6697b3b814a5850299849283, model: EVA-CLIP updated successfully.
# Document with ID 6697b3b814a5850299849284, model: Luminous dataset updated successfully.
# Document with ID 6697b3b814a5850299849285, model: Luminous updated successfully.
# Document with ID 6697b3b814a5850299849286, model: Aleph Alpha API updated successfully.
# Document with ID 6697b3b814a5850299849287, model: MAGMA updated successfully.
# Document with ID 6697b3b814a5850299849288, model: Robin AI updated successfully.
# Document with ID 6697b3b814a5850299849289, model: Juni Tutor Bot updated successfully.
# Document with ID 6697b3b814a585029984928a, model: LAION-1B updated successfully.
# Document with ID 6697b3b814a585029984928b, model: Composer updated successfully.
# Document with ID 6697b3b814a585029984928c, model: Qwen updated successfully.
# Document with ID 6697b3b814a585029984928d, model: Qwen 1.5 updated successfully.
# Document with ID 6697b3b814a585029984928e, model: Qwen 1.5 MoE updated successfully.
# Document with ID 6697b3b814a585029984928f, model: SeaLLM v2.5 updated successfully.
# Document with ID 6697b3b814a5850299849290, model: OpenWebMath updated successfully.
# Document with ID 6697b3b814a5850299849291, model: Orion updated successfully.
# Document with ID 6697b3b814a5850299849292, model: SambaLingo updated successfully.
# Document with ID 6697b3b814a5850299849293, model: Samba 1 updated successfully.
# Document with ID 6697b3b814a5850299849294, model: LP-MusicCaps updated successfully.
# Document with ID 6697b3b814a5850299849295, model: SciPhi Mistral updated successfully.
# Document with ID 6697b3b814a5850299849296, model: Notus updated successfully.
# Document with ID 6697b3b814a5850299849297, model: Amber updated successfully.
# Document with ID 6697b3b814a5850299849298, model: CrystalCoder updated successfully.
# Document with ID 6697b3b814a5850299849299, model: Duolingo Explain My Answer updated successfully.
# Document with ID 6697b3b814a585029984929a, model: Duolingo Max updated successfully.
# Document with ID 6697b3b814a585029984929b, model: Duolingo Role Play updated successfully.

# %% [markdown]
# #### Join objectIDs of models with dependency

# %%
def update_dependencies_id():
    llm_collection = db['llm_dependencies']
    for doc in llm_collection.find():
        updates = {}
        object_id_list = []
        dependecies_ids = doc["dependencies_llm_ids"]
        document_id = doc["_id"]
        # Get model objectID from llm_datas for each model id
        #print(dependecies_ids)
        for id in dependecies_ids:
            #print(id)
            if id != None:
                #print(id)
                # Lookup id in main llm table
                llm_data_table = db['llm_datas']
                referenced_doc = llm_data_table.find_one({'llm_data_id': id})
                #print(f'{referenced_doc["name"]}: {referenced_doc["_id"]}')
                object_id_list.append(referenced_doc["_id"])
            else:
                object_id_list.append(id)

        print(f'Ids to add: {object_id_list}')
        updates['dependencies_llm_ids'] = object_id_list
        result = llm_collection.update_one({"_id": document_id}, {"$set": updates})
        
        if result.matched_count > 0:
            print(f"Document with ID {document_id} updated successfully.")
        else:
            print(f"No document found with ID {document_id}.")

update_dependencies_id()
# Out:
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c50945 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491bd')]
# Document with ID 669a3ac8db0298c298c50946 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50947 updated successfully.
# Ids to add: [None, None, ObjectId('6697b3b814a585029984911d')]
# Document with ID 669a3ac8db0298c298c50948 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849267'), ObjectId('6697b3b814a5850299849170'), ObjectId('6697b3b814a585029984920e'), None, ObjectId('6697b3b814a58502998491e5'), ObjectId('6697b3b814a5850299849210')]
# Document with ID 669a3ac8db0298c298c50949 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849184'), None]
# Document with ID 669a3ac8db0298c298c5094a updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c5094b updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491fa')]
# Document with ID 669a3ac8db0298c298c5094c updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491f7'), ObjectId('6697b3b814a58502998491f6')]
# Document with ID 669a3ac8db0298c298c5094d updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491f9')]
# Document with ID 669a3ac8db0298c298c5094e updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491f8')]
# Document with ID 669a3ac8db0298c298c5094f updated successfully.
# Ids to add: [None, None, ObjectId('6697b3b814a58502998490f5'), ObjectId('6697b3b814a5850299849220'), ObjectId('6697b3b814a58502998490ec'), None, None]
# Document with ID 669a3ac8db0298c298c50950 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849130')]
# Document with ID 669a3ac8db0298c298c50951 updated successfully.
# Ids to add: [None, None, None, None, None, None, None, None, None, None]
# Document with ID 669a3ac8db0298c298c50952 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a58502998491d0')]
# Document with ID 669a3ac8db0298c298c50953 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50954 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849236')]
# Document with ID 669a3ac8db0298c298c50955 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849205'), ObjectId('6697b3b814a5850299849203')]
# Document with ID 669a3ac8db0298c298c50956 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849205')]
# Document with ID 669a3ac8db0298c298c50957 updated successfully.
# Ids to add: [None, None, None, None]
# Document with ID 669a3ac8db0298c298c50958 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490f5'), ObjectId('6697b3b814a5850299849224'), None, None]
# Document with ID 669a3ac8db0298c298c50959 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490f5')]
# Document with ID 669a3ac8db0298c298c5095a updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984914e')]
# Document with ID 669a3ac8db0298c298c5095b updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849157'), None]
# Document with ID 669a3ac8db0298c298c5095c updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849157'), ObjectId('6697b3b814a5850299849224'), None, ObjectId('6697b3b814a5850299849098')]
# Document with ID 669a3ac8db0298c298c5095d updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849157'), ObjectId('6697b3b814a5850299849225')]
# Document with ID 669a3ac8db0298c298c5095e updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849157'), ObjectId('6697b3b814a58502998490f9')]
# Document with ID 669a3ac8db0298c298c5095f updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849157'), ObjectId('6697b3b814a5850299849210')]
# Document with ID 669a3ac8db0298c298c50960 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849157'), None, None]
# Document with ID 669a3ac8db0298c298c50961 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849157')]
# Document with ID 669a3ac8db0298c298c50962 updated successfully.
# Ids to add: [None, None, ObjectId('6697b3b814a5850299849180'), None, None, None, ObjectId('6697b3b814a58502998490f7'), None]
# Document with ID 669a3ac8db0298c298c50963 updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c50964 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849167'), ObjectId('6697b3b814a5850299849171'), None, ObjectId('6697b3b814a585029984916c'), ObjectId('6697b3b814a585029984916b')]
# Document with ID 669a3ac8db0298c298c50965 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849167'), None]
# Document with ID 669a3ac8db0298c298c50966 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849167')]
# Document with ID 669a3ac8db0298c298c50967 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984915e')]
# Document with ID 669a3ac8db0298c298c50968 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849188'), ObjectId('6697b3b814a58502998490fb'), ObjectId('6697b3b814a585029984918c'), ObjectId('6697b3b814a585029984918d')]
# Document with ID 669a3ac8db0298c298c50969 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849188'), ObjectId('6697b3b814a585029984918e')]
# Document with ID 669a3ac8db0298c298c5096a updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849188'), ObjectId('6697b3b814a585029984918f')]
# Document with ID 669a3ac8db0298c298c5096b updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849188')]
# Document with ID 669a3ac8db0298c298c5096c updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c5096d updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491fb'), ObjectId('6697b3b814a58502998491fc')]
# Document with ID 669a3ac8db0298c298c5096e updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491ef'), ObjectId('6697b3b814a58502998491a0')]
# Document with ID 669a3ac8db0298c298c5096f updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849154')]
# Document with ID 669a3ac8db0298c298c50970 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849251'), ObjectId('6697b3b814a5850299849252')]
# Document with ID 669a3ac8db0298c298c50971 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849251')]
# Document with ID 669a3ac8db0298c298c50972 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849254'), ObjectId('6697b3b814a5850299849253')]
# Document with ID 669a3ac8db0298c298c50973 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849256'), ObjectId('6697b3b814a5850299849257'), ObjectId('6697b3b814a5850299849258'), ObjectId('6697b3b814a5850299849259')]
# Document with ID 669a3ac8db0298c298c50974 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849290'), None, ObjectId('6697b3b814a5850299849076')]
# Document with ID 669a3ac8db0298c298c50975 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50976 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491c4')]
# Document with ID 669a3ac8db0298c298c50977 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a58502998490f5'), None, None, None, None, None]
# Document with ID 669a3ac8db0298c298c50978 updated successfully.
# Ids to add: [None, None, None]
# Document with ID 669a3ac8db0298c298c50979 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c5097a updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490f7'), ObjectId('6697b3b814a5850299849180'), None, None, None, None]
# Document with ID 669a3ac8db0298c298c5097b updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491c6')]
# Document with ID 669a3ac8db0298c298c5097c updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491c7')]
# Document with ID 669a3ac8db0298c298c5097d updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490dc')]
# Document with ID 669a3ac8db0298c298c5097e updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a585029984914e'), ObjectId('6697b3b814a585029984915e')]
# Document with ID 669a3ac8db0298c298c5097f updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984914f'), ObjectId('6697b3b814a585029984914e')]
# Document with ID 669a3ac8db0298c298c50980 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984914f')]
# Document with ID 669a3ac8db0298c298c50981 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984921b')]
# Document with ID 669a3ac8db0298c298c50982 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984919f')]
# Document with ID 669a3ac8db0298c298c50983 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a58502998491ce')]
# Document with ID 669a3ac8db0298c298c50984 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984916e')]
# Document with ID 669a3ac8db0298c298c50985 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984929b'), ObjectId('6697b3b814a5850299849299')]
# Document with ID 669a3ac8db0298c298c50986 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491ee'), ObjectId('6697b3b814a5850299849157'), ObjectId('6697b3b814a58502998490f9')]
# Document with ID 669a3ac8db0298c298c50987 updated successfully.
# Ids to add: [None, None, ObjectId('6697b3b814a58502998491d8')]
# Document with ID 669a3ac8db0298c298c50988 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849266'), ObjectId('6697b3b814a58502998490ec')]
# Document with ID 669a3ac8db0298c298c50989 updated successfully.
# Ids to add: [None, None, None, ObjectId('6697b3b814a5850299849266'), None, None, ObjectId('6697b3b814a5850299849246'), ObjectId('6697b3b814a585029984924a')]
# Document with ID 669a3ac8db0298c298c5098a updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849249')]
# Document with ID 669a3ac8db0298c298c5098b updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849235')]
# Document with ID 669a3ac8db0298c298c5098c updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849221')]
# Document with ID 669a3ac8db0298c298c5098d updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984921f')]
# Document with ID 669a3ac8db0298c298c5098e updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849176'), ObjectId('6697b3b814a58502998490b0'), ObjectId('6697b3b814a58502998490f5'), None]
# Document with ID 669a3ac8db0298c298c5098f updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849140'), ObjectId('6697b3b814a5850299849141'), ObjectId('6697b3b814a5850299849142')]
# Document with ID 669a3ac8db0298c298c50990 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849202'), ObjectId('6697b3b814a585029984919b')]
# Document with ID 669a3ac8db0298c298c50991 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849109'), ObjectId('6697b3b814a5850299849108')]
# Document with ID 669a3ac8db0298c298c50992 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50993 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849234')]
# Document with ID 669a3ac8db0298c298c50994 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50995 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984910f'), None, ObjectId('6697b3b814a5850299849110'), ObjectId('6697b3b814a5850299849111'), None, ObjectId('6697b3b814a5850299849112')]
# Document with ID 669a3ac8db0298c298c50996 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849152'), None, ObjectId('6697b3b814a5850299849165')]
# Document with ID 669a3ac8db0298c298c50997 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984914b')]
# Document with ID 669a3ac8db0298c298c50998 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849153'), ObjectId('6697b3b814a585029984914d'), ObjectId('6697b3b814a585029984914c')]
# Document with ID 669a3ac8db0298c298c50999 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849153'), ObjectId('6697b3b814a5850299849154'), ObjectId('6697b3b814a5850299849163'), ObjectId('6697b3b814a5850299849164'), ObjectId('6697b3b814a5850299849165'), ObjectId('6697b3b814a585029984915f'), ObjectId('6697b3b814a5850299849156'), ObjectId('6697b3b814a5850299849158'), ObjectId('6697b3b814a5850299849170'), ObjectId('6697b3b814a5850299849160')]
# Document with ID 669a3ac8db0298c298c5099a updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849153'), ObjectId('6697b3b814a585029984915b')]
# Document with ID 669a3ac8db0298c298c5099b updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849153'), ObjectId('6697b3b814a58502998490b0')]
# Document with ID 669a3ac8db0298c298c5099c updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849231')]
# Document with ID 669a3ac8db0298c298c5099d updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849170'), ObjectId('6697b3b814a5850299849118')]
# Document with ID 669a3ac8db0298c298c5099e updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849171'), None, None, ObjectId('6697b3b814a5850299849247'), ObjectId('6697b3b814a5850299849105')]
# Document with ID 669a3ac8db0298c298c5099f updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849171')]
# Document with ID 669a3ac8db0298c298c509a0 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849170'), ObjectId('6697b3b814a58502998491fb'), ObjectId('6697b3b814a585029984921f')]
# Document with ID 669a3ac8db0298c298c509a1 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849170'), None]
# Document with ID 669a3ac8db0298c298c509a2 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849170'), None]
# Document with ID 669a3ac8db0298c298c509a3 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849170')]
# Document with ID 669a3ac8db0298c298c509a4 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b1'), ObjectId('6697b3b814a5850299849266')]
# Document with ID 669a3ac8db0298c298c509a5 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b1'), ObjectId('6697b3b814a5850299849157')]
# Document with ID 669a3ac8db0298c298c509a6 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b1'), ObjectId('6697b3b814a5850299849202'), ObjectId('6697b3b814a585029984919b')]
# Document with ID 669a3ac8db0298c298c509a7 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849071'), ObjectId('6697b3b814a5850299849075')]
# Document with ID 669a3ac8db0298c298c509a8 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b3'), None, None]
# Document with ID 669a3ac8db0298c298c509a9 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b3'), ObjectId('6697b3b814a5850299849074')]
# Document with ID 669a3ac8db0298c298c509aa updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b3')]
# Document with ID 669a3ac8db0298c298c509ab updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c509ac updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849183')]
# Document with ID 669a3ac8db0298c298c509ad updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849138'), None]
# Document with ID 669a3ac8db0298c298c509ae updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984913a')]
# Document with ID 669a3ac8db0298c298c509af updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c509b0 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c509b1 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c509b2 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849187'), ObjectId('6697b3b814a58502998490fb'), ObjectId('6697b3b814a5850299849191')]
# Document with ID 669a3ac8db0298c298c509b3 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849187'), ObjectId('6697b3b814a58502998490fb')]
# Document with ID 669a3ac8db0298c298c509b4 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849187'), ObjectId('6697b3b814a5850299849192')]
# Document with ID 669a3ac8db0298c298c509b5 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984906a')]
# Document with ID 669a3ac8db0298c298c509b6 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849076')]
# Document with ID 669a3ac8db0298c298c509b7 updated successfully.
# Ids to add: [None, None, ObjectId('6697b3b814a585029984928a')]
# Document with ID 669a3ac8db0298c298c509b8 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490fc')]
# Document with ID 669a3ac8db0298c298c509b9 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490c9')]
# Document with ID 669a3ac8db0298c298c509ba updated successfully.
# Ids to add: [None, None, None, None, None, None, None]
# Document with ID 669a3ac8db0298c298c509bb updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490f6')]
# Document with ID 669a3ac8db0298c298c509bc updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490fa'), ObjectId('6697b3b814a5850299849113')]
# Document with ID 669a3ac8db0298c298c509bd updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c509be updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c509bf updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491b7')]
# Document with ID 669a3ac8db0298c298c509c0 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491b9'), ObjectId('6697b3b814a58502998491b8')]
# Document with ID 669a3ac8db0298c298c509c1 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491b9'), ObjectId('6697b3b814a58502998491ba'), ObjectId('6697b3b814a58502998491bb'), ObjectId('6697b3b814a58502998491be'), ObjectId('6697b3b814a58502998491bd')]
# Document with ID 669a3ac8db0298c298c509c2 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491bb'), ObjectId('6697b3b814a58502998491fb'), ObjectId('6697b3b814a5850299849097'), None, ObjectId('6697b3b814a58502998491fd'), ObjectId('6697b3b814a5850299849252')]
# Document with ID 669a3ac8db0298c298c509c3 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491bb')]
# Document with ID 669a3ac8db0298c298c509c4 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849199'), ObjectId('6697b3b814a5850299849198'), ObjectId('6697b3b814a58502998491d0'), None, None, None]
# Document with ID 669a3ac8db0298c298c509c5 updated successfully.
# Ids to add: [None, None, None, None]
# Document with ID 669a3ac8db0298c298c509c6 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849224'), None]
# Document with ID 669a3ac8db0298c298c509c7 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849224'), ObjectId('6697b3b814a5850299849116')]
# Document with ID 669a3ac8db0298c298c509c8 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849224')]
# Document with ID 669a3ac8db0298c298c509c9 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849225'), ObjectId('6697b3b814a5850299849198'), None]
# Document with ID 669a3ac8db0298c298c509ca updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849225')]
# Document with ID 669a3ac8db0298c298c509cb updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c509cc updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849159')]
# Document with ID 669a3ac8db0298c298c509cd updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c509ce updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a58502998490ee'), ObjectId('6697b3b814a5850299849220'), None, None, None, None]
# Document with ID 669a3ac8db0298c298c509cf updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a58502998491a0')]
# Document with ID 669a3ac8db0298c298c509d0 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c509d1 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e5'), ObjectId('6697b3b814a5850299849157')]
# Document with ID 669a3ac8db0298c298c509d2 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e5'), None, None]
# Document with ID 669a3ac8db0298c298c509d3 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e5'), None, ObjectId('6697b3b814a5850299849266')]
# Document with ID 669a3ac8db0298c298c509d4 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e5'), None]
# Document with ID 669a3ac8db0298c298c509d5 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e5'), None]
# Document with ID 669a3ac8db0298c298c509d6 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e5'), None]
# Document with ID 669a3ac8db0298c298c509d7 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e5'), None]
# Document with ID 669a3ac8db0298c298c509d8 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e5')]
# Document with ID 669a3ac8db0298c298c509d9 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849266')]
# Document with ID 669a3ac8db0298c298c509da updated successfully.
# Ids to add: [None, None, None, None]
# Document with ID 669a3ac8db0298c298c509db updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491b3')]
# Document with ID 669a3ac8db0298c298c509dc updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490fd')]
# Document with ID 669a3ac8db0298c298c509dd updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984909a')]
# Document with ID 669a3ac8db0298c298c509de updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491d1'), None, ObjectId('6697b3b814a585029984924a'), None, None]
# Document with ID 669a3ac8db0298c298c509df updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e6'), ObjectId('6697b3b814a5850299849205')]
# Document with ID 669a3ac8db0298c298c509e0 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e6'), ObjectId('6697b3b814a58502998490a4'), ObjectId('6697b3b814a5850299849221'), ObjectId('6697b3b814a585029984921b'), ObjectId('6697b3b814a5850299849205'), None, ObjectId('6697b3b814a5850299849157')]
# Document with ID 669a3ac8db0298c298c509e1 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e6')]
# Document with ID 669a3ac8db0298c298c509e2 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849284')]
# Document with ID 669a3ac8db0298c298c509e3 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849285')]
# Document with ID 669a3ac8db0298c298c509e4 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849182'), None, None, None, ObjectId('6697b3b814a5850299849188')]
# Document with ID 669a3ac8db0298c298c509e5 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849227')]
# Document with ID 669a3ac8db0298c298c509e6 updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c509e7 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849114')]
# Document with ID 669a3ac8db0298c298c509e8 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e3')]
# Document with ID 669a3ac8db0298c298c509e9 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849181')]
# Document with ID 669a3ac8db0298c298c509ea updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a58502998491e5'), ObjectId('6697b3b814a58502998491ef')]
# Document with ID 669a3ac8db0298c298c509eb updated successfully.
# Ids to add: [None, None, None, None, None, None, None]
# Document with ID 669a3ac8db0298c298c509ec updated successfully.
# Ids to add: [None, None, None]
# Document with ID 669a3ac8db0298c298c509ed updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849238'), ObjectId('6697b3b814a5850299849239')]
# Document with ID 669a3ac8db0298c298c509ee updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849238')]
# Document with ID 669a3ac8db0298c298c509ef updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490a4'), ObjectId('6697b3b814a58502998490a5')]
# Document with ID 669a3ac8db0298c298c509f0 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490a4'), None, ObjectId('6697b3b814a5850299849269')]
# Document with ID 669a3ac8db0298c298c509f1 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490a4'), None]
# Document with ID 669a3ac8db0298c298c509f2 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490a4')]
# Document with ID 669a3ac8db0298c298c509f3 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c509f4 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984911c'), None, ObjectId('6697b3b814a5850299849122'), ObjectId('6697b3b814a5850299849123'), ObjectId('6697b3b814a5850299849124')]
# Document with ID 669a3ac8db0298c298c509f5 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c509f6 updated successfully.
# Ids to add: [None, None, None]
# Document with ID 669a3ac8db0298c298c509f7 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c509f8 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984911e')]
# Document with ID 669a3ac8db0298c298c509f9 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c509fa updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491b4')]
# Document with ID 669a3ac8db0298c298c509fb updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491b5')]
# Document with ID 669a3ac8db0298c298c509fc updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849126'), ObjectId('6697b3b814a5850299849125')]
# Document with ID 669a3ac8db0298c298c509fd updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849127')]
# Document with ID 669a3ac8db0298c298c509fe updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849269'), None]
# Document with ID 669a3ac8db0298c298c509ff updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984908f'), None, ObjectId('6697b3b814a5850299849225'), ObjectId('6697b3b814a58502998491dd')]
# Document with ID 669a3ac8db0298c298c50a00 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e2'), None]
# Document with ID 669a3ac8db0298c298c50a01 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e2')]
# Document with ID 669a3ac8db0298c298c50a02 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a03 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a04 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490e2'), None, None]
# Document with ID 669a3ac8db0298c298c50a05 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490e2'), None, ObjectId('6697b3b814a5850299849100')]
# Document with ID 669a3ac8db0298c298c50a06 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984915b')]
# Document with ID 669a3ac8db0298c298c50a07 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849169')]
# Document with ID 669a3ac8db0298c298c50a08 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984916a')]
# Document with ID 669a3ac8db0298c298c50a09 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984926d'), None]
# Document with ID 669a3ac8db0298c298c50a0a updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984924a'), None]
# Document with ID 669a3ac8db0298c298c50a0b updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849290'), ObjectId('6697b3b814a5850299849076'), None, ObjectId('6697b3b814a585029984928c')]
# Document with ID 669a3ac8db0298c298c50a0c updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849202'), ObjectId('6697b3b814a585029984919b'), None]
# Document with ID 669a3ac8db0298c298c50a0d updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849202')]
# Document with ID 669a3ac8db0298c298c50a0e updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a0f updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491dd')]
# Document with ID 669a3ac8db0298c298c50a10 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a585029984912e'), None]
# Document with ID 669a3ac8db0298c298c50a11 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a12 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490fe')]
# Document with ID 669a3ac8db0298c298c50a13 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849104'), ObjectId('6697b3b814a585029984910b'), ObjectId('6697b3b814a5850299849202'), ObjectId('6697b3b814a585029984919b')]
# Document with ID 669a3ac8db0298c298c50a14 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849104'), ObjectId('6697b3b814a58502998490fe')]
# Document with ID 669a3ac8db0298c298c50a15 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849104'), ObjectId('6697b3b814a585029984912f')]
# Document with ID 669a3ac8db0298c298c50a16 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849104'), None, ObjectId('6697b3b814a58502998490fe'), ObjectId('6697b3b814a585029984912b')]
# Document with ID 669a3ac8db0298c298c50a17 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849104')]
# Document with ID 669a3ac8db0298c298c50a18 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984912e'), None]
# Document with ID 669a3ac8db0298c298c50a19 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984920c'), None]
# Document with ID 669a3ac8db0298c298c50a1a updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490ab'), ObjectId('6697b3b814a585029984915b')]
# Document with ID 669a3ac8db0298c298c50a1b updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b8'), ObjectId('6697b3b814a58502998491ef')]
# Document with ID 669a3ac8db0298c298c50a1c updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a1d updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a1e updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c50a1f updated successfully.
# Ids to add: [None, None, None]
# Document with ID 669a3ac8db0298c298c50a20 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984928c'), ObjectId('6697b3b814a585029984924a'), None]
# Document with ID 669a3ac8db0298c298c50a21 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984928c'), ObjectId('6697b3b814a585029984924a')]
# Document with ID 669a3ac8db0298c298c50a22 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849201')]
# Document with ID 669a3ac8db0298c298c50a23 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a58502998490ee')]
# Document with ID 669a3ac8db0298c298c50a24 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a25 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849076'), ObjectId('6697b3b814a58502998490f5'), ObjectId('6697b3b814a58502998490ee'), ObjectId('6697b3b814a585029984919d')]
# Document with ID 669a3ac8db0298c298c50a26 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849076'), ObjectId('6697b3b814a58502998490b0'), ObjectId('6697b3b814a5850299849220'), ObjectId('6697b3b814a58502998490ee'), None, ObjectId('6697b3b814a5850299849290')]
# Document with ID 669a3ac8db0298c298c50a27 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849076')]
# Document with ID 669a3ac8db0298c298c50a28 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849220'), ObjectId('6697b3b814a58502998490b0'), ObjectId('6697b3b814a5850299849076'), ObjectId('6697b3b814a585029984919f'), None]
# Document with ID 669a3ac8db0298c298c50a29 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849220')]
# Document with ID 669a3ac8db0298c298c50a2a updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a58502998490b0'), None]
# Document with ID 669a3ac8db0298c298c50a2b updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491e8')]
# Document with ID 669a3ac8db0298c298c50a2c updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c50a2d updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984919c'), None, ObjectId('6697b3b814a58502998490f9')]
# Document with ID 669a3ac8db0298c298c50a2e updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984916d')]
# Document with ID 669a3ac8db0298c298c50a2f updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a30 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491ac'), ObjectId('6697b3b814a58502998490ec')]
# Document with ID 669a3ac8db0298c298c50a31 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491ac')]
# Document with ID 669a3ac8db0298c298c50a32 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984911a'), ObjectId('6697b3b814a585029984911b'), ObjectId('6697b3b814a585029984911c'), ObjectId('6697b3b814a585029984911f'), ObjectId('6697b3b814a5850299849120')]
# Document with ID 669a3ac8db0298c298c50a33 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849098')]
# Document with ID 669a3ac8db0298c298c50a34 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849097'), None]
# Document with ID 669a3ac8db0298c298c50a35 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849097')]
# Document with ID 669a3ac8db0298c298c50a36 updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849266'), None, None, None, None]
# Document with ID 669a3ac8db0298c298c50a37 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a38 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490f9'), ObjectId('6697b3b814a5850299849157'), ObjectId('6697b3b814a5850299849197')]
# Document with ID 669a3ac8db0298c298c50a39 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490f9'), None, ObjectId('6697b3b814a5850299849272')]
# Document with ID 669a3ac8db0298c298c50a3a updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490f9'), ObjectId('6697b3b814a585029984910b'), ObjectId('6697b3b814a5850299849202'), ObjectId('6697b3b814a585029984919b'), None]
# Document with ID 669a3ac8db0298c298c50a3b updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490f9'), ObjectId('6697b3b814a5850299849202')]
# Document with ID 669a3ac8db0298c298c50a3c updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490f9')]
# Document with ID 669a3ac8db0298c298c50a3d updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849094')]
# Document with ID 669a3ac8db0298c298c50a3e updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491df')]
# Document with ID 669a3ac8db0298c298c50a3f updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b0'), None, ObjectId('6697b3b814a5850299849226'), ObjectId('6697b3b814a5850299849224'), ObjectId('6697b3b814a5850299849148'), ObjectId('6697b3b814a58502998490f7')]
# Document with ID 669a3ac8db0298c298c50a40 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b0'), None, ObjectId('6697b3b814a5850299849202'), None]
# Document with ID 669a3ac8db0298c298c50a41 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b0'), None, ObjectId('6697b3b814a58502998491e5'), None]
# Document with ID 669a3ac8db0298c298c50a42 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b0'), None]
# Document with ID 669a3ac8db0298c298c50a43 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490b0')]
# Document with ID 669a3ac8db0298c298c50a44 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a45 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490ee'), None]
# Document with ID 669a3ac8db0298c298c50a46 updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490ee')]
# Document with ID 669a3ac8db0298c298c50a47 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984910c'), ObjectId('6697b3b814a585029984910b'), ObjectId('6697b3b814a5850299849202'), ObjectId('6697b3b814a585029984919b')]
# Document with ID 669a3ac8db0298c298c50a48 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849100'), ObjectId('6697b3b814a5850299849118')]
# Document with ID 669a3ac8db0298c298c50a49 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984912c')]
# Document with ID 669a3ac8db0298c298c50a4a updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998490c2')]
# Document with ID 669a3ac8db0298c298c50a4b updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491d8'), ObjectId('6697b3b814a585029984908d')]
# Document with ID 669a3ac8db0298c298c50a4c updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c50a4d updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849157')]
# Document with ID 669a3ac8db0298c298c50a4e updated successfully.
# Ids to add: [None, None, None, None, ObjectId('6697b3b814a58502998490f7'), ObjectId('6697b3b814a58502998490f8'), ObjectId('6697b3b814a5850299849180'), ObjectId('6697b3b814a58502998491af')]
# Document with ID 669a3ac8db0298c298c50a4f updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849210'), ObjectId('6697b3b814a5850299849157')]
# Document with ID 669a3ac8db0298c298c50a50 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849210'), ObjectId('6697b3b814a5850299849280')]
# Document with ID 669a3ac8db0298c298c50a51 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849151')]
# Document with ID 669a3ac8db0298c298c50a52 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849198'), None, None]
# Document with ID 669a3ac8db0298c298c50a53 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849198')]
# Document with ID 669a3ac8db0298c298c50a54 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849166')]
# Document with ID 669a3ac8db0298c298c50a55 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849150')]
# Document with ID 669a3ac8db0298c298c50a56 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849156'), None, ObjectId('6697b3b814a5850299849210')]
# Document with ID 669a3ac8db0298c298c50a57 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849156')]
# Document with ID 669a3ac8db0298c298c50a58 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849246')]
# Document with ID 669a3ac8db0298c298c50a59 updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a5a updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984927d')]
# Document with ID 669a3ac8db0298c298c50a5b updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a58502998491b1')]
# Document with ID 669a3ac8db0298c298c50a5c updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c50a5d updated successfully.
# Ids to add: [None, None, None, None, None]
# Document with ID 669a3ac8db0298c298c50a5e updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849277')]
# Document with ID 669a3ac8db0298c298c50a5f updated successfully.
# Ids to add: [ObjectId('6697b3b814a58502998491ce')]
# Document with ID 669a3ac8db0298c298c50a60 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984917d')]
# Document with ID 669a3ac8db0298c298c50a61 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984917e')]
# Document with ID 669a3ac8db0298c298c50a62 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984912d'), None, None]
# Document with ID 669a3ac8db0298c298c50a63 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984912d')]
# Document with ID 669a3ac8db0298c298c50a64 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849162')]
# Document with ID 669a3ac8db0298c298c50a65 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849163')]
# Document with ID 669a3ac8db0298c298c50a66 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849250')]
# Document with ID 669a3ac8db0298c298c50a67 updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849161')]
# Document with ID 669a3ac8db0298c298c50a68 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984915f'), ObjectId('6697b3b814a5850299849169')]
# Document with ID 669a3ac8db0298c298c50a69 updated successfully.
# Ids to add: [None, None]
# Document with ID 669a3ac8db0298c298c50a6a updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a585029984925d')]
# Document with ID 669a3ac8db0298c298c50a6b updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849132'), ObjectId('6697b3b814a5850299849133')]
# Document with ID 669a3ac8db0298c298c50a6c updated successfully.
# Ids to add: [None, ObjectId('6697b3b814a5850299849203')]
# Document with ID 669a3ac8db0298c298c50a6d updated successfully.
# Ids to add: [None]
# Document with ID 669a3ac8db0298c298c50a6e updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849164')]
# Document with ID 669a3ac8db0298c298c50a6f updated successfully.
# Ids to add: [ObjectId('6697b3b814a5850299849165')]
# Document with ID 669a3ac8db0298c298c50a70 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984911b'), ObjectId('6697b3b814a585029984911a')]
# Document with ID 669a3ac8db0298c298c50a71 updated successfully.
# Ids to add: [ObjectId('6697b3b814a585029984915d')]
# Document with ID 669a3ac8db0298c298c50a72 updated successfully.
# Ids to add: []
# Document with ID 669a3ac8db0298c298c50a73 updated successfully.
