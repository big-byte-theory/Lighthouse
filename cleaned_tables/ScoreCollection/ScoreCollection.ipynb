# %%
import json
from pprint import pprint
from pathlib import Path
import os
from collections import defaultdict

# %%
# Define the path to the JSON file
file_path = Path('benchmark_output_lite/runs/v1.5.0')
test_path = ''
model_path = r'commonsense,dataset=openbookqa,method=multiple_choice_joint,model=google_gemini-1.5-flash-001/stats.json'

path = Path('benchmark_output_lite/runs/v1.5.0/commonsense,dataset=openbookqa,method=multiple_choice_joint,model=google_gemini-1.5-flash-001/stats.json')
# Concatenate paths
full_path = file_path / model_path

# Print the constructed path to verify
print(f"Constructed path: {full_path}")

# Ensure the constructed path exists before trying to open it
if path.exists():
    # Open and load the JSON file
    with path.open('r') as file:
        data = json.load(file)
    
    # Accessing the data
    pprint(data)
else:
    print(f"The file at {full_path} does not exist.")


# quasi_exact_match = score
# exact_match
# Out:
# Constructed path: benchmark_output_lite\runs\v1.5.0\commonsense,dataset=openbookqa,method=multiple_choice_joint,model=google_gemini-1.5-flash-001\stats.json
# [{'count': 1,
#   'max': 4.0,
#   'mean': 4.0,
#   'min': 4.0,
#   'name': {'name': 'num_references', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 4.0,
#   'sum_squared': 16.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'num_train_trials', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 248.508,
#   'mean': 248.508,
#   'min': 248.508,
#   'name': {'name': 'num_prompt_tokens', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 248.508,
#   'sum_squared': 61756.226064,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_completion_tokens', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_output_tokens', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 0,
#   'name': {'name': 'training_co2_cost', 'split': 'test'},
#   'sum': 0,
#   'sum_squared': 0},
#  {'count': 0,
#   'name': {'name': 'training_energy_cost', 'split': 'test'},
#   'sum': 0,
#   'sum_squared': 0},
#  {'count': 1,
#   'max': 0.5038927392959595,
#   'mean': 0.5038927392959595,
#   'min': 0.5038927392959595,
#   'name': {'name': 'inference_runtime', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.5038927392959595,
#   'sum_squared': 0.25390789271518577,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'batch_size', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'finish_reason_length', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'finish_reason_stop', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'finish_reason_endoftext', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'finish_reason_unknown', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 5.0,
#   'mean': 5.0,
#   'min': 5.0,
#   'name': {'name': 'num_train_instances', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 5.0,
#   'sum_squared': 25.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'prompt_truncated', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'max_prob', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'exact_match', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'exact_match@5', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_exact_match', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_exact_match@5', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'prefix_exact_match', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'prefix_exact_match@5', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_prefix_exact_match', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_prefix_exact_match@5', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'logprob', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_perplexity_tokens', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_bytes', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 4.0,
#   'mean': 4.0,
#   'min': 4.0,
#   'name': {'name': 'num_references',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 4.0,
#   'sum_squared': 16.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 4.0,
#   'mean': 4.0,
#   'min': 4.0,
#   'name': {'name': 'num_references',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 4.0,
#   'sum_squared': 16.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'num_train_trials',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'num_train_trials',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 248.508,
#   'mean': 248.508,
#   'min': 248.508,
#   'name': {'name': 'num_prompt_tokens',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 248.508,
#   'sum_squared': 61756.226064,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 248.508,
#   'mean': 248.508,
#   'min': 248.508,
#   'name': {'name': 'num_prompt_tokens',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 248.508,
#   'sum_squared': 61756.226064,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_completion_tokens',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_completion_tokens',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_output_tokens',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_output_tokens',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.5038927392959595,
#   'mean': 0.5038927392959595,
#   'min': 0.5038927392959595,
#   'name': {'name': 'inference_runtime',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.5038927392959595,
#   'sum_squared': 0.25390789271518577,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.5038927392959595,
#   'mean': 0.5038927392959595,
#   'min': 0.5038927392959595,
#   'name': {'name': 'inference_runtime',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.5038927392959595,
#   'sum_squared': 0.25390789271518577,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'batch_size',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'batch_size',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'finish_reason_length',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'finish_reason_length',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'finish_reason_stop',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'finish_reason_stop',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'finish_reason_endoftext',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'finish_reason_endoftext',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'finish_reason_unknown',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'finish_reason_unknown',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 5.0,
#   'mean': 5.0,
#   'min': 5.0,
#   'name': {'name': 'num_train_instances',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 5.0,
#   'sum_squared': 25.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 5.0,
#   'mean': 5.0,
#   'min': 5.0,
#   'name': {'name': 'num_train_instances',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 5.0,
#   'sum_squared': 25.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'prompt_truncated',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'prompt_truncated',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'max_prob',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 1.0,
#   'mean': 1.0,
#   'min': 1.0,
#   'name': {'name': 'max_prob',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 1.0,
#   'sum_squared': 1.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'exact_match',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'exact_match',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'exact_match@5',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'exact_match@5',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_exact_match',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_exact_match',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_exact_match@5',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_exact_match@5',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'prefix_exact_match',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'prefix_exact_match',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'prefix_exact_match@5',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'prefix_exact_match@5',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_prefix_exact_match',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_prefix_exact_match',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_prefix_exact_match@5',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.928,
#   'mean': 0.928,
#   'min': 0.928,
#   'name': {'name': 'quasi_prefix_exact_match@5',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.928,
#   'sum_squared': 0.8611840000000001,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'logprob',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'logprob',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_perplexity_tokens',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_perplexity_tokens',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_bytes',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': False,
#                             'name': 'robustness',
#                             'robustness': True},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 0.0,
#   'mean': 0.0,
#   'min': 0.0,
#   'name': {'name': 'num_bytes',
#            'perturbation': {'computed_on': 'worst',
#                             'fairness': True,
#                             'name': 'fairness',
#                             'robustness': False},
#            'split': 'test'},
#   'stddev': 0.0,
#   'sum': 0.0,
#   'sum_squared': 0.0,
#   'variance': 0.0},
#  {'count': 1,
#   'max': 500.0,
#   'mean': 500.0,
#   'min': 500.0,
#   'name': {'name': 'num_instances', 'split': 'test'},
#   'stddev': 0.0,
#   'sum': 500.0,
#   'sum_squared': 250000.0,
#   'variance': 0.0}]

# %%
from pathlib import Path
import json
from collections import defaultdict

# Define the root directory
root_dir = Path('benchmark_output_lite/runs/v1.5.0')

# Initialize a dictionary to store the data
results = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

# Loop through all directories
for json_file in root_dir.rglob('stats.json'):
    
    # Extract information from the directory name
    parts = str(json_file.relative_to(root_dir)).split(',')
    if len(parts) >= 4:
        test_name = parts[0]
        dataset = parts[1].split('=')[1]
        method = parts[2].split('=')[1]
        model_name = parts[3].split('=')[1].split('-')[1]
    print(parts)
    break
# Out:
# ['commonsense', 'dataset=openbookqa', 'method=multiple_choice_joint', 'model=01-ai_yi-large-preview\\stats.json']

# %%
# Define the root directory
root_dir = Path('benchmark_output_lite/runs/v1.5.0')


# Define the specific metrics for each test
test_metrics = {
    'narrative_qa': 'f1_score',
    'natural_qa': 'f1_score',
    'commonsense': 'exact_match',
    'openbook': 'exact_match',
    'mmlu': 'exact_match',
    'wmt_14': 'bleu_4',
    'med_qa': 'quasi_exact_match',
    'math': 'math_equiv_chain_of_thought',
    'legalbench': 'quasi_exact_match',
    'gsm': 'final_number_exact_match'
}

# Function to extract information and read stats.json
def process_json_file(json_file):
    
    # Extract information from the directory name
    parts = str(json_file.relative_to(root_dir)).split(',')
    test_name = parts[0]
    dataset = method = model_name = subset = subject = mode = lang_pair = None
    if test_name == 'commonsense': 
        dataset = parts[1].split('=')[1]
        method = parts[2].split('=')[1]
        model_name = parts[3].split('=')[1].split(os.sep)[0]
    elif test_name == 'gsm':       
        model_name = parts[1].split('=')[1].split(os.sep)[0]
    elif test_name == 'legalbench':
        subset = parts[1].split('=')[1]
        model_name = parts[2].split('=')[1].split(os.sep)[0]
    elif test_name == 'math':
        subject = parts[1].split('=')[1]      
        model_name = parts[5].split('=')[1].split(os.sep)[0]
    elif test_name == 'med_qa':
        model_name = parts[1].split('=')[1].split(os.sep)[0]
    elif test_name == 'mmlu':
        subject = parts[1].split('=')[1]      
        method = parts[2].split('=')[1]
        model_name = parts[3].split('=')[1].split(os.sep)[0]
    elif test_name == 'narrative_qa':
        model_name = parts[1].split('=')[1].split(os.sep)[0]
    elif test_name == 'natural_qa':
        mode = parts[1].split('=')[1]      
        model_name = parts[2].split('=')[1].split(os.sep)[0]
    elif test_name == 'wmt_14':
        lang_pair = parts[1].split('=')[1]
        model_name = parts[2].split('=')[1].split(os.sep)[0]
    else:
        print(test_name + ' isn\'t set up')

    # Read the stats.json file
    with open(json_file, 'r') as file:
        data = json.load(file)


     # Extract the score using the specific metric for the test
    metric = test_metrics.get(test_name, None)
    split = 'valid' if test_name == 'natural_qa' else 'test'
    if not metric:
        print(f"No metric defined for test {test_name}")
        return None
    
    # Extract the score
    score = None
    for entry in data:
        if entry['name']['name'] == metric and entry['name']['split'] == split:
            score = entry['mean']
            #print(f'score: {score}')
            break
   
    if score is not None:
       
         # Structure the extracted data
        test_result = {
            #'model_name': model_name,
            'test_name': test_name,
            'metric': metric,
            'score': score
        }
        
        if dataset:
            test_result['dataset'] = dataset
        if method:
            test_result['method'] = method
        if subset:
            test_result['subset'] = subset
        if subject:
            test_result['subject'] = subject
        if mode:
            test_result['mode'] = mode
        if lang_pair:
            test_result['language_pair'] = lang_pair
        
        return model_name, test_result
    else:
        print(f"No exact match test score found in {json_file}")
        return None

# Dictionary to store results
model_results = defaultdict(lambda: defaultdict(list))

# Loop through all directories and process stats.json files
for json_file in root_dir.rglob('stats.json'):
    result = process_json_file(json_file)
    if result:
        model_name, test_result = result
        test_name = test_result['test_name']
        
         # Check for subset or subject and organize accordingly
        subset_info = {
            'score': test_result['score']
        }
        if 'subset' in test_result:
            subset_info['subset'] = test_result['subset']
        if 'subject' in test_result:
            subset_info['subject'] = test_result['subject']
        if 'mode' in test_result:
            subset_info['mode'] = test_result['mode']
        if 'language_pair' in test_result:
            subset_info['language_pair'] = test_result['language_pair']
        
        model_results[model_name][test_name].append(subset_info)


# Convert to desired JSON format
final_results = {}
for model_name, tests in model_results.items():
    final_results[model_name] = []
    for test_name, results in tests.items():
        test_entry = {
            'test_name': test_name,
            'metric': test_metrics[test_name],
            'subsets': results
        }
        final_results[model_name].append(test_entry)



# Print the final JSON document
json_object = json.dumps(final_results, indent=2)
print(json_object)
# Writing to sample.json
with open("scores_v1.5.json", "w") as outfile:
    outfile.write(json_object)
